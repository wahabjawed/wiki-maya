# %%
import pandas as pd

user_data = pd.read_csv("csv/all_user_data_c_50_90_s.csv")

# %%
user_data.drop(user_data.columns[[0]], axis=1, inplace=True)
user_data.head()
# Out:
#      id              name  editcount  status
# 0   228            !dea4u          1       1
# 1  1350        $uperFan32          1       1
# 2  2346         ***Ria777          1       1
# 3  2460  *AirportUpdater*          1       1
# 4  2555             *Kat*          1       1

# %%
user_data = user_data[user_data['status']>0]
user_data = user_data[:1500]  # same as df.head(10)

# %%
user_data.describe().apply(lambda s: s.apply(lambda x: format(x, 'g')))
# Out:
#                 id editcount status
# count         1500      1500   1500
# mean   1.52381e+06         1      1
# std         820612         0      0
# min            228         1      1
# 25%         801058         1      1
# 50%    1.56195e+06         1      1
# 75%     2.2514e+06         1      1
# max    2.88764e+06         1      1

# %%
import os.path
import numpy as np
from trust_score import TrustScore
from sklearn import metrics
from sklearn.linear_model import LinearRegression
import json

y_pred = []
y_test=[]
cou = 0

for row in user_data.iterrows():
    path = 'user_data_50_90_b_e/rev_list_' + str(row[1]['id']) + '-dp.json'
    #print(path)
    try:
        with open(path, 'r') as infile:
            data = json.loads(infile.read())

            if len(data) > 0:
                for d in data:
                    del d['next_rev']

                graph_for = "longevityRev"

                series = pd.DataFrame(data=data)
                series = series[['pageid', 'timestamp', graph_for]]
                series = series[series.longevityRev >= 0]
                if len(series) > 1:
                    print('User ID: ', str(row[1]['id']))
                    series['longevityRevA'] = series.iloc[:,2].rolling(window=4).mean()
                    series['longevityRevA'] = series['longevityRevA'].apply(lambda x: round(x, 1))
                    series.iloc[0:3,3]=series.iloc[0:3,2]
                    #series['longevityRev'] = series['longevityRevA']
                    #print(series.head())
                    series['Trust'] = TrustScore([series[graph_for],48]).calculate()
                    series['longevityRevN'] = series['longevityRev'].shift(-1)
                    series = series[series.longevityRevN >= 0]
                    series = series[series.longevityRev >= 0]
                    
                    

                    seriesTrain = series[0:-1]
                    seriesTest = series[len(series)-1:]
                    #print(series)
                    regressor = LinearRegression()
                    regressor.fit(seriesTrain[['longevityRevA']], seriesTrain['longevityRevN'])

                    # To retrieve the intercept:
                    print(regressor.intercept_)
                    # For retrieving the slope:
                    print(regressor.coef_)

                    pred = regressor.predict(seriesTest[['longevityRevA']])
                    print('Data Count: ', len(seriesTrain))
                    print('Test Data: ')
                    print(seriesTest[['Trust', 'longevityRev','longevityRevP']])
                    print('predicted: ',pred, ' actual: ', seriesTest['longevityRevN'].values[0])
                    print("##########################")
                    if(pred>=0):
                        y_test.append(seriesTest['longevityRev'].values[0])
                        y_pred.append(pred[0])
    except Exception as e:
        #print('error :',e.message)
        cou= cou+1

correlation_matrix = np.corrcoef(y_test, y_pred)
correlation_xy = correlation_matrix[0,1]
print('R 2 value:', correlation_xy**2)
# Out:
# User ID:  2346
# 3.3940283036906242
# [0.19989352]
# Data Count:  106
# Test Data:
#         Trust  longevityRev  longevityRevP
# 132  0.110139           0.0            0.0
# predicted:  [4.55341072]  actual:  0.0
# ##########################
# User ID:  3201
# 9.555851600859516
# [0.29130606]
# Data Count:  273
# Test Data:
#         Trust  longevityRev  longevityRevP
# 310  0.177145           9.0            5.0
# predicted:  [14.85762184]  actual:  0.0
# ##########################
# User ID:  3437
# 18.077948048238007
# [-0.65623278]
# Data Count:  18
# Test Data:
#        Trust  longevityRev  longevityRevP
# 24  0.140484           0.0            2.0
# predicted:  [8.89068909]  actual:  13.0
# ##########################
# User ID:  3469
# 18.64920909345071
# [-0.48968882]
# Data Count:  10
# Test Data:
#        Trust  longevityRev  longevityRevP
# 22  0.752315          48.0            0.0
# predicted:  [12.5280989]  actual:  6.0
# ##########################
# User ID:  4191
# 12.145130994998965
# [0.05017518]
# Data Count:  170
# Test Data:
#         Trust  longevityRev  longevityRevP
# 264  0.441099          48.0           34.0
# predicted:  [13.17372212]  actual:  43.0
# ##########################
# User ID:  6537
# 10.035217748763698
# [0.113159]
# Data Count:  16
# Test Data:
#        Trust  longevityRev  longevityRevP
# 42  0.132021           8.0            2.0
# predicted:  [10.31811526]  actual:  1.0
# ##########################
# User ID:  9763
# 9.907073794184747
# [0.37710835]
# Data Count:  214
# Test Data:
#         Trust  longevityRev  longevityRevP
# 303  0.225584          20.0            1.0
# predicted:  [11.9811697]  actual:  16.0
# ##########################
# User ID:  23317
# 18.80783234311913
# [-1.05586712]
# Data Count:  9
# Test Data:
#       Trust  longevityRev  longevityRevP
# 16  0.14208           0.0            8.0
# predicted:  [2.75865215]  actual:  48.0
# ##########################
# User ID:  27313
# 22.175486047813067
# [-0.49993563]
# Data Count:  17
# Test Data:
#        Trust  longevityRev  longevityRevP
# 35  0.127063           0.0           14.0
# predicted:  [14.17651603]  actual:  2.0
# ##########################
# User ID:  31377
# 11.112013223930028
# [0.21860213]
# Data Count:  288
# Test Data:
#         Trust  longevityRev  longevityRevP
# 343  0.171512          20.0            4.0
# predicted:  [12.5985077]  actual:  35.0
# ##########################
# User ID:  35003
# 28.26658164064311
# [-0.02899696]
# Data Count:  9
# Test Data:
#        Trust  longevityRev  longevityRevP
# 10  0.250663             2           48.0
# predicted:  [27.20819244]  actual:  2.0
# ##########################
# User ID:  38287
# 11.666566015413276
# [-0.00944245]
# Data Count:  138
# Test Data:
#         Trust  longevityRev  longevityRevP
# 229  0.023054           3.0            0.0
# predicted:  [11.62879622]  actual:  0.0
# ##########################
# User ID:  38661
# 44.60878894526029
# [-1.1500337]
# Data Count:  13
# Test Data:
#        Trust  longevityRev  longevityRevP
# 16  0.488425          30.0            3.0
# predicted:  [21.37810829]  actual:  0.0
# ##########################
# User ID:  40647
# 11.39310445868561
# [-0.1541178]
# Data Count:  40
# Test Data:
#        Trust  longevityRev  longevityRevP
# 74  0.111097           5.0           18.0
# predicted:  [10.00604427]  actual:  0.0
# ##########################
# User ID:  40914
# 15.261856588999173
# [0.26088785]
# Data Count:  325
# Test Data:
#         Trust  longevityRev  longevityRevP
# 390  0.035315           0.0            7.0
# predicted:  [17.03589395]  actual:  0.0
# ##########################
# User ID:  42012
# 16.07270538948366
# [0.19618807]
# Data Count:  178
# Test Data:
#         Trust  longevityRev  longevityRevP
# 245  0.172641          12.0            0.0
# predicted:  [19.0155264]  actual:  21.0
# ##########################
# User ID:  42231
# 9.251309323716796
# [0.14719604]
# Data Count:  47
# Test Data:
#        Trust  longevityRev  longevityRevP
# 53  0.262074          44.0            8.0
# predicted:  [14.6975629]  actual:  2.0
# ##########################
# User ID:  44492
# 34.79263337746039
# [-0.26273412]
# Data Count:  49
# Test Data:
#        Trust  longevityRev  longevityRevP
# 74  0.014066           1.0            1.0
# predicted:  [31.50845692]  actual:  38.0
# ##########################
# User ID:  44729
# 20.508762241161843
# [-0.08269548]
# Data Count:  64
# Test Data:
#     Trust  longevityRev  longevityRevP
# 88    0.0           0.0            0.0
# predicted:  [20.02912844]  actual:  48.0
# ##########################
# User ID:  45328
# 10.529252303170235
# [0.36419234]
# Data Count:  39
# Test Data:
#     Trust  longevityRev  longevityRevP
# 79    0.0           0.0            5.0
# predicted:  [18.83283758]  actual:  0.0
# ##########################
# User ID:  46792
# 8.086378054600942
# [0.52271545]
# Data Count:  20
# Test Data:
#        Trust  longevityRev  longevityRevP
# 48  0.634448          48.0            0.0
# predicted:  [21.78152295]  actual:  0.0
# ##########################
# User ID:  49456
# 13.655249270707003
# [-0.36169655]
# Data Count:  8
# Test Data:
#        Trust  longevityRev  longevityRevP
# 28  0.146336           2.0            4.0
# predicted:  [12.20846308]  actual:  0.0
# ##########################
# User ID:  49472
# 19.007113976429995
# [-0.2803166]
# Data Count:  25
# Test Data:
#       Trust  longevityRev  longevityRevP
# 50  0.06711           0.0           48.0
# predicted:  [11.43856584]  actual:  15.0
# ##########################
# User ID:  50394
# 12.214691498059043
# [0.03108631]
# Data Count:  122
# Test Data:
#        Trust  longevityRev  longevityRevP
# 185  0.02742           0.0            0.0
# predicted:  [12.2146915]  actual:  0.0
# ##########################
# User ID:  51393
# 16.701890365531703
# [0.20420016]
# Data Count:  47
# Test Data:
#        Trust  longevityRev  longevityRevP
# 88  0.393085          28.0           28.0
# predicted:  [22.41949485]  actual:  28.0
# ##########################
# User ID:  57409
# 16.69633033830573
# [0.00096361]
# Data Count:  285
# Test Data:
#         Trust  longevityRev  longevityRevP
# 381  0.008365          28.0           28.0
# predicted:  [16.72331156]  actual:  0.0
# ##########################
# User ID:  127449
# 19.13925290177452
# [0.06020937]
# Data Count:  86
# Test Data:
#         Trust  longevityRev  longevityRevP
# 183  0.014772          48.0            0.0
# predicted:  [20.2832309]  actual:  35.0
# ##########################
# User ID:  128695
# 16.226122741057267
# [0.0671156]
# Data Count:  102
# Test Data:
#        Trust  longevityRev  longevityRevP
# 163  0.21443           8.0           48.0
# predicted:  [18.13891723]  actual:  4.0
# ##########################
# User ID:  130515
# 18.099731832601485
# [0.42065577]
# Data Count:  33
# Test Data:
#        Trust  longevityRev  longevityRevP
# 36  0.034064           0.0           48.0
# predicted:  [33.24333956]  actual:  48.0
# ##########################
# User ID:  132017
# 20.38617274982332
# [-0.17683529]
# Data Count:  12
# Test Data:
#        Trust  longevityRev  longevityRevP
# 21  0.310478           9.0           14.0
# predicted:  [18.58245275]  actual:  48.0
# ##########################
# User ID:  133301
# 14.411465426223739
# [-0.34451364]
# Data Count:  7
# Test Data:
#        Trust  longevityRev  longevityRevP
# 10  0.147802           0.0            0.0
# predicted:  [7.24558169]  actual:  0.0
# ##########################
# User ID:  134007
# 12.953605561893102
# [0.06321263]
# Data Count:  41
# Test Data:
#        Trust  longevityRev  longevityRevP
# 68  0.032601          18.0           48.0
# predicted:  [13.99661389]  actual:  3.0
# ##########################
# User ID:  135320
# 14.726584342963651
# [-1.19757689]
# Data Count:  8
# Test Data:
#        Trust  longevityRev  longevityRevP
# 14  0.095157           0.0            8.0
# predicted:  [10.53506524]  actual:  48.0
# ##########################
# User ID:  135386
# 8.745031550918805
# [0.51633855]
# Data Count:  349
# Test Data:
#         Trust  longevityRev  longevityRevP
# 425  0.535061          38.0           48.0
# predicted:  [22.58290477]  actual:  21.0
# ##########################
# User ID:  135764
# 16.516823519728245
# [0.25310103]
# Data Count:  65
# Test Data:
#         Trust  longevityRev  longevityRevP
# 116  0.477032          48.0            0.0
# predicted:  [21.88256532]  actual:  0.0
# ##########################
# User ID:  137279
# 0.8913940324282834
# [-0.21970642]
# Data Count:  8
# Test Data:
#        Trust  longevityRev  longevityRevP
# 17  0.037616           1.0            2.0
# predicted:  [0.67168761]  actual:  0.0
# ##########################
# User ID:  140762
# 15.791597659269073
# [-0.01366346]
# Data Count:  21
# Test Data:
#       Trust  longevityRev  longevityRevP
# 27  0.62371          48.0           16.0
# predicted:  [15.40902065]  actual:  1.0
# ##########################
# User ID:  141895
# 9.841827036292539
# [-0.17699285]
# Data Count:  16
# Test Data:
#        Trust  longevityRev  longevityRevP
# 39  0.204848          13.0            6.0
# predicted:  [8.95686279]  actual:  0.0
# ##########################
# User ID:  142583
# 24.62644708212339
# [-0.21856799]
# Data Count:  16
# Test Data:
#        Trust  longevityRev  longevityRevP
# 19  0.156486           3.0           48.0
# predicted:  [20.36437131]  actual:  1.0
# ##########################
# User ID:  142659
# 11.437542314640446
# [0.32084285]
# Data Count:  128
# Test Data:
#         Trust  longevityRev  longevityRevP
# 171  0.077746           0.0           48.0
# predicted:  [19.45861367]  actual:  0.0
# ##########################
# User ID:  144508
# 2.559503820717538
# [2.65497036]
# Data Count:  8
# Test Data:
#       Trust  longevityRev  longevityRevP
# 9  0.735702            48            2.0
# predicted:  [47.69399993]  actual:  7.0
# ##########################
# User ID:  144745
# 19.894094745071254
# [0.04890743]
# Data Count:  124
# Test Data:
#         Trust  longevityRev  longevityRevP
# 209  0.443091          48.0           26.0
# predicted:  [21.28795639]  actual:  0.0
# ##########################
# User ID:  146343
# 17.95100608278678
# [0.26953115]
# Data Count:  274
# Test Data:
#         Trust  longevityRev  longevityRevP
# 340  0.031874           0.0            0.0
# predicted:  [18.00491231]  actual:  0.0
# ##########################
# User ID:  304993
# 7.771848882646659
# [0.48819922]
# Data Count:  335
# Test Data:
#        Trust  longevityRev  longevityRevP
# 421  0.05612          48.0           12.0
# predicted:  [15.48539654]  actual:  34.0
# ##########################
# User ID:  305514
# 37.29065361102775
# [-0.49410872]
# Data Count:  24
# Test Data:
#        Trust  longevityRev  longevityRevP
# 44  0.209441          19.0           48.0
# predicted:  [28.89080531]  actual:  0.0
# ##########################
# User ID:  306136
# 13.125675914382697
# [0.06052889]
# Data Count:  12
# Test Data:
#        Trust  longevityRev  longevityRevP
# 16  0.148565           6.0            0.0
# predicted:  [13.47674346]  actual:  0.0
# ##########################
# User ID:  306268
# 23.626316181432856
# [-0.67497253]
# Data Count:  37
# Test Data:
#        Trust  longevityRev  longevityRevP
# 58  0.065742           3.0           22.0
# predicted:  [10.80183802]  actual:  13.0
# ##########################
# User ID:  306282
# 9.953470918438258
# [0.00735092]
# Data Count:  189
# Test Data:
#         Trust  longevityRev  longevityRevP
# 244  0.183168          16.0            0.0
# predicted:  [9.99610624]  actual:  0.0
# ##########################
# User ID:  307345
# 25.92525583017574
# [-0.40129689]
# Data Count:  13
# Test Data:
#      Trust  longevityRev  longevityRevP
# 28  0.4852          48.0           11.0
# predicted:  [14.60868363]  actual:  0.0
# ##########################
# User ID:  308073
# 14.80333255120696
# [0.40118836]
# Data Count:  135
# Test Data:
#      Trust  longevityRev  longevityRevP
# 204    0.0           0.0            0.0
# predicted:  [19.61759286]  actual:  48.0
# ##########################
# User ID:  319377
# 12.009717882753502
# [-0.1583915]
# Data Count:  22
# Test Data:
#        Trust  longevityRev  longevityRevP
# 46  0.545923          48.0            3.0
# predicted:  [8.08160866]  actual:  10.0
# ##########################
# User ID:  320293
# 10.632254359121372
# [0.06037523]
# Data Count:  98
# Test Data:
#         Trust  longevityRev  longevityRevP
# 103  0.050406           2.0            0.0
# predicted:  [11.3869447]  actual:  48.0
# ##########################
# User ID:  322373
# 55.16015051346115
# [-0.53661115]
# Data Count:  20
# Test Data:
#        Trust  longevityRev  longevityRevP
# 32  0.536484          48.0           48.0
# predicted:  [33.80302672]  actual:  48.0
# ##########################
# User ID:  323450
# 16.327294762985463
# [-0.15655199]
# Data Count:  156
# Test Data:
#        Trust  longevityRev  longevityRevP
# 314  0.05717           2.0            1.0
# predicted:  [14.32342928]  actual:  48.0
# ##########################
# User ID:  339046
# 6.691062715416894
# [0.501694]
# Data Count:  264
# Test Data:
#      Trust  longevityRev  longevityRevP
# 385    0.0           0.0           48.0
# predicted:  [12.71139073]  actual:  0.0
# ##########################
# User ID:  339309
# 6.762872815718204
# [0.23909943]
# Data Count:  15
# Test Data:
#        Trust  longevityRev  longevityRevP
# 22  0.099321           1.0            0.0
# predicted:  [7.1932518]  actual:  0.0
# ##########################
# User ID:  628181
# 10.597620130362285
# [-0.12600424]
# Data Count:  7
# Test Data:
#        Trust  longevityRev  longevityRevP
# 12  0.250372          10.0            0.0
# predicted:  [8.39254585]  actual:  0.0
# ##########################
# User ID:  806888
# 9.277967463346053
# [-0.4759992]
# Data Count:  15
# Test Data:
#       Trust  longevityRev  longevityRevP
# 20  0.06211           0.0            0.0
# predicted:  [9.27796746]  actual:  48.0
# ##########################
# User ID:  975741
# 29.036394195282647
# [-0.23327404]
# Data Count:  93
# Test Data:
#         Trust  longevityRev  longevityRevP
# 132  0.039131          48.0            0.0
# predicted:  [23.25119789]  actual:  1.0
# ##########################
# User ID:  1035125
# 8.040171504796344
# [0.46920578]
# Data Count:  153
# Test Data:
#         Trust  longevityRev  longevityRevP
# 261  0.114873          11.0           26.0
# predicted:  [17.98733398]  actual:  48.0
# ##########################
# User ID:  1629974
# 8.611335437427545
# [0.30487981]
# Data Count:  61
# Test Data:
#        Trust  longevityRev  longevityRevP
# 95  0.182742          28.0            1.0
# predicted:  [15.07478736]  actual:  6.0
# ##########################
# User ID:  2760801
# 10.199116654087831
# [-0.32546649]
# Data Count:  33
# Test Data:
#        Trust  longevityRev  longevityRevP
# 65  0.078859           0.0            0.0
# predicted:  [6.13078548]  actual:  3.0
# ##########################
# User ID:  2823489
# 10.010577237084373
# [0.50150386]
# Data Count:  13
# Test Data:
#        Trust  longevityRev  longevityRevP
# 14  0.679344            43            0.0
# predicted:  [24.30343735]  actual:  0.0
# ##########################
# Mean Absolute Error: 14.698568366563258
# R value: 0.3593629114230454
# R 2 value: 0.12914170210644757
# Mean Squared Error: 320.2048038925386
# Root Mean Squared Error: 17.894267347185206

# %%
longevity_list = pd.DataFrame({'actual':y_test, 'predicted':y_pred})
longevity_list.to_csv("all_user_data_predicted.csv")

# %%
longevity_list.describe()
# Out:
#           actual  predicted
# count  63.000000  63.000000
# mean   16.496032  16.356086
# std    10.224742   7.989038
# min     0.000000   0.983499
# 25%     6.750000  10.893878
# 50%    16.500000  15.164225
# 75%    24.750000  20.297620
# max    39.750000  45.406269

# %%
longevity_list = longevity_list[longevity_list['actual']>5]

# %%
longevity_list.describe()
# Out:
#            actual   predicted
# count  155.000000  155.000000
# mean     0.759677    1.013659
# std      2.536564    2.968929
# min      0.000000    0.000000
# 25%      0.000000    0.009143
# 50%      0.000000    0.153736
# 75%      0.250000    0.747056
# max     22.250000   30.686348

# %%
longevity_list['sum'] = longevity_list['actual']+longevity_list['predicted']

# %%
longevity_list.describe()
# Out:
#            actual   predicted         sum       error
# count  586.000000  586.000000  586.000000  586.000000
# mean    27.573379   27.611827   55.185206   -0.038448
# std     10.768333   10.126758   19.474796    7.599263
# min      5.250000    1.481666    9.574922  -19.100161
# 25%     19.500000   19.964361   40.453350   -5.578922
# 50%     27.000000   27.555240   54.823573   -0.091775
# 75%     36.000000   35.070486   70.003419    5.173237
# max     48.000000   53.933310  101.933310   26.141187

# %%
correlation_matrix = np.corrcoef(longevity_list['actual'], longevity_list['predicted'])
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print('R value:', correlation_xy)
print('R 2 value:', r_squared)
# Out:
# R value: 0.6393325631730091
# R 2 value: 0.4087461263333697

# %%
longevity_list['error'] = longevity_list['actual']-longevity_list['predicted']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(x=longevity_list['predicted'], y=longevity_list['error'])
plt.show()

# %%
longevity_list = longevity_list[longevity_list['actual']<40]

# %%
correlation_matrix = np.corrcoef(longevity_list['predicted'], longevity_list['error'])
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print('R value:', correlation_xy)
print('R 2 value:', r_squared)
# Out:
# R value: -0.20195327079883205
# R 2 value: 0.04078512358634639

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(x=longevity_list['actual'], y=longevity_list['error'])
plt.show()

# %%
correlation_matrix = np.corrcoef(longevity_list['actual'], longevity_list['error'])
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print('R value:', correlation_xy)
print('R 2 value:', r_squared)
# Out:
# R value: 0.6437399874472487
# R 2 value: 0.4144011714385839

# %%
longevity_list['actual'].hist(bins=10)
plt.xlabel("Longevity", fontsize=15)
plt.ylabel("Count",fontsize=15)
# Out:
# Text(0, 0.5, 'Count')
