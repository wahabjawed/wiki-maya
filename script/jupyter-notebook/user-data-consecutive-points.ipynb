# %%
import pandas as pd

user_data = pd.read_csv("all_user_data_c_50_95.csv")

# %%
user_data.drop(user_data.columns[[0]], axis=1, inplace=True)
user_data.head()
# Out:
#     id                          name  editcount  status
# 0   15                            !!          1       1
# 1  228                        !dea4u          1       1
# 2  387  "Country" Bushrod Washington       1652       0
# 3  582                       "Yahia"       1023       0
# 4  829               $1LENCE D00600D      18642       0

# %%
user_data = user_data[user_data['status']>0]
user_data.describe().apply(lambda s: s.apply(lambda x: format(x, 'g')))
# Out:
#                 id editcount status
# count         2885      2885   2885
# mean   3.12261e+06         1      1
# std    1.56652e+06         0      0
# min             15         1      1
# 25%    1.85180e+06         1      1
# 50%    3.24545e+06         1      1
# 75%    4.39629e+06         1      1
# max    5.80923e+06         1      1

# %%
import os.path
import numpy as np
from trust_score import TrustScore
from sklearn import metrics
from sklearn.linear_model import LinearRegression
import json

y_pred = []
y_test=[]
cou = 0

for row in user_data.iterrows():
    path = 'user_data_50_95/rev_list_' + str(row[1]['id']) + '-d.json'
    #print(path)
    try:
        with open(path, 'r') as infile:
            data = json.loads(infile.read())

            if len(data) > 0:
                for d in data:
                    del d['next_rev']

                graph_for = "longevityRev"

                series = pd.DataFrame(data=data)
                series = series[['pageid', 'timestamp', graph_for]]
                series = series[series.longevityRev >= 0]
                if len(series) > 9:
                    print('User ID: ', str(row[1]['id']))
                    series['Trust'] = TrustScore([series[graph_for],48]).calculate()
                    series['longevityRevN'] = series['longevityRev'].shift(-1)
                    series['longevityRevP'] = series['longevityRev'].shift(1)
                    series = series[series.longevityRevP >= 0]
                    series = series[series.longevityRevN >= 0]
                    series = series[series.longevityRev >= 0]

                    index = 8
                    #print(series)
                    while (index < len(series)):
                        seriesTrain = series[0:index]
                        seriesTest = series[index:index+1]
#                         print(seriesTrain)
                        #print(seriesTest)
                        regressor = LinearRegression()
                        regressor.fit(seriesTrain[['Trust', 'longevityRev','longevityRevP']], seriesTrain['longevityRevN'])

                        pred = regressor.predict(seriesTest[['Trust', 'longevityRev','longevityRevP']])
                        print('Data Count: ', len(seriesTrain))
                        print('Test Data: ')
                        print(seriesTest[['Trust', 'longevityRev','longevityRevP']])
                        print('predicted: ',pred, ' actual: ', seriesTest['longevityRevN'].values[0])
                        print("##########################")
                        if(pred>=0):
                            y_test.append(seriesTest['longevityRevN'].values[0])
                            y_pred.append(pred)
                        index = index +1
    except Exception as e:
        print('error :')
        cou= cou+1

print(str(cou))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('R2 Score:', metrics.r2_score(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# User ID:  15
# Data Count:  8
# Test Data:
#        Trust  longevityRev  longevityRevP
# 17  0.753506          48.0            0.0
# predicted:  [4.96620189]  actual:  2.0
# ##########################
# Data Count:  9
# Test Data:
#        Trust  longevityRev  longevityRevP
# 18  0.256132           2.0           48.0
# predicted:  [-12.44174241]  actual:  48.0
# ##########################
# Data Count:  10
# Test Data:
#        Trust  longevityRev  longevityRevP
# 19  0.732153          48.0            2.0
# predicted:  [-2.44568095]  actual:  7.0
# ##########################
# Data Count:  11
# Test Data:
#        Trust  longevityRev  longevityRevP
# 20  0.332946           7.0           48.0
# predicted:  [17.3310332]  actual:  2.0
# ##########################
# Data Count:  12
# Test Data:
#        Trust  longevityRev  longevityRevP
# 21  0.255637           2.0            7.0
# predicted:  [41.83448298]  actual:  40.0
# ##########################
# Data Count:  13
# Test Data:
#        Trust  longevityRev  longevityRevP
# 22  0.510523          40.0            2.0
# predicted:  [-13.89341049]  actual:  48.0
# ##########################
# Data Count:  14
# Test Data:
#        Trust  longevityRev  longevityRevP
# 23  0.657773          48.0           40.0
# predicted:  [-2.53105627]  actual:  48.0
# ##########################
# Data Count:  15
# Test Data:
#        Trust  longevityRev  longevityRevP
# 24  0.588902          48.0           48.0
# predicted:  [30.56587881]  actual:  2.0
# ##########################
# Data Count:  16
# Test Data:
#        Trust  longevityRev  longevityRevP
# 25  0.212649           2.0           48.0
# predicted:  [21.00440303]  actual:  17.0
# ##########################
# Data Count:  17
# Test Data:
#        Trust  longevityRev  longevityRevP
# 26  0.269341          17.0            2.0
# predicted:  [21.44819947]  actual:  1.0
# ##########################
# Data Count:  18
# Test Data:
#        Trust  longevityRev  longevityRevP
# 27  0.124547           1.0           17.0
# predicted:  [20.85347751]  actual:  6.0
# ##########################
# Data Count:  19
# Test Data:
#        Trust  longevityRev  longevityRevP
# 28  0.138795           6.0            1.0
# predicted:  [18.95684321]  actual:  11.0
# ##########################
# Data Count:  20
# Test Data:
#        Trust  longevityRev  longevityRevP
# 29  0.151986          11.0            6.0
# predicted:  [17.10939237]  actual:  21.0
# ##########################
# Data Count:  21
# Test Data:
#        Trust  longevityRev  longevityRevP
# 30  0.243077          21.0           11.0
# predicted:  [16.66105289]  actual:  0.0
# ##########################
# Data Count:  22
# Test Data:
#        Trust  longevityRev  longevityRevP
# 31  0.081348           0.0           21.0
# predicted:  [17.23404759]  actual:  15.0
# ##########################
# Data Count:  23
# Test Data:
#        Trust  longevityRev  longevityRevP
# 32  0.180343          15.0            0.0
# predicted:  [14.73386119]  actual:  9.0
# ##########################
# Data Count:  24
# Test Data:
#        Trust  longevityRev  longevityRevP
# 33  0.149701           9.0           15.0
# predicted:  [15.12561629]  actual:  48.0
# ##########################
# Data Count:  25
# Test Data:
#        Trust  longevityRev  longevityRevP
# 34  0.386841          48.0            9.0
# predicted:  [11.66436517]  actual:  0.0
# ##########################
# Data Count:  26
# Test Data:
#        Trust  longevityRev  longevityRevP
# 35  0.078173           0.0           48.0
# predicted:  [18.15639346]  actual:  48.0
# ##########################
# Data Count:  27
# Test Data:
#        Trust  longevityRev  longevityRevP
# 36  0.336167          48.0            0.0
# predicted:  [7.86570949]  actual:  48.0
# ##########################
# Data Count:  28
# Test Data:
#        Trust  longevityRev  longevityRevP
# 37  0.242339          48.0           48.0
# predicted:  [29.02249624]  actual:  1.0
# ##########################
# Data Count:  29
# Test Data:
#        Trust  longevityRev  longevityRevP
# 38  0.071477           1.0           48.0
# predicted:  [21.79119911]  actual:  48.0
# ##########################
# Data Count:  30
# Test Data:
#        Trust  longevityRev  longevityRevP
# 39  0.161137          48.0            1.0
# predicted:  [15.97641756]  actual:  2.0
# ##########################
# Data Count:  31
# Test Data:
#        Trust  longevityRev  longevityRevP
# 40  0.029398           2.0           48.0
# predicted:  [24.94294307]  actual:  2.0
# ##########################
# Data Count:  32
# Test Data:
#        Trust  longevityRev  longevityRevP
# 41  0.018473           2.0            2.0
# predicted:  [20.00160506]  actual:  48.0
# ##########################
# Data Count:  33
# Test Data:
#        Trust  longevityRev  longevityRevP
# 42  0.009157          48.0            2.0
# predicted:  [12.30019965]  actual:  48.0
# ##########################
# Data Count:  34
# Test Data:
#        Trust  longevityRev  longevityRevP
# 43  0.009553          48.0           48.0
# predicted:  [24.44567024]  actual:  48.0
# ##########################
# Data Count:  35
# Test Data:
#     Trust  longevityRev  longevityRevP
# 44    0.0          48.0           48.0
# predicted:  [32.53431964]  actual:  48.0
# ##########################
# Data Count:  36
# Test Data:
#        Trust  longevityRev  longevityRevP
# 45  0.010407          48.0           48.0
# predicted:  [36.1098379]  actual:  1.0
# ##########################
# Data Count:  37
# Test Data:
#        Trust  longevityRev  longevityRevP
# 46  0.153172           1.0           48.0
# predicted:  [22.91349461]  actual:  48.0
# ##########################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-77609ffb540d> in <module>
#      43                         #print(seriesTest)
#      44                         regressor = LinearRegression()
# ---> 45                         regressor.fit(seriesTrain[['Trust', 'longevityRev','longevityRevP']], seriesTrain['longevityRevN'])
#      46
#      47                         pred = regressor.predict(seriesTest[['Trust', 'longevityRev','longevityRevP']])
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2810             indexer = np.where(indexer)[0]
#    2811
# -> 2812         data = self._take_with_is_copy(indexer, axis=1)
#    2813
#    2814         if is_single_key:
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3407         See the docstring of `take` for full explanation of the parameters.
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#    3411         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3392         self._consolidate_inplace()
#    3393
# -> 3394         new_data = self._data.take(
#    3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1391
#    1392         new_labels = self.axes[axis].take(indexer)
# -> 1393         return self.reindex_indexer(
#    1394             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1395         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1255
#    1256         if axis == 0:
# -> 1257             new_blocks = self._slice_take_blocks_ax0(indexer, fill_tuple=(fill_value,))
#    1258         else:
#    1259             new_blocks = [
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple)
#    1315                 self._blknos, slobj, fill_value=-1, allow_fill=allow_fill
#    1316             )
# -> 1317             blklocs = algos.take_1d(
#    1318                 self._blklocs, slobj, fill_value=-1, allow_fill=allow_fill
#    1319             )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1660         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1661     )
# -> 1662     func(arr, indexer, out, fill_value)
#    1663
#    1664     if flip_order:
#
# KeyboardInterrupt:
